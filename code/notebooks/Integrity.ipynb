# %% [markdown]
# ### CS-396: Exercises on Cryptographic Integrity
# #### Author: Devharsh Trivedi (dtrived5@stevens.edu)
# \

# %% [markdown]
# Ex.1) Identify the hash function and message for the digest "**C4F3ACA26A244839355883DDC951083C1056FFBC**".
#
# Messages => { Stevens, stevens, STEVENS }
#
# Hint: https://www.pelock.com/products/hash-calculator
# \

# %% [markdown]
# Ex.2) Calculate MD5 and SHA2 for the following messages.
#
# Messages => { par**i**s, par**t**s, par**k**s }
#
# Calcualte the number of differing characters.
# \

# %% [markdown]
# Ex.3) Calculate MD5 and SHA2 for the two **.ps** files in **psdocs.zip**.
#
# Messages => { order.ps, recommend.ps }
#
# Hint: https://gchq.github.io/CyberChef
# \

# %% [markdown]
# Ex.4) Construct a simple HMAC<sub>K</sub> = H( **K** || **M** ).
# \

# %% [markdown]
# Ex.5) Construct a more secure HMAC<sub>K</sub> = H( (**K** ⊕ opad) || H( (**K** ⊕ ipad) || **M** ) ).
# \

# %% [markdown]
# Ex.6) Construct a CBC-MAC of M denoted by E<sub>K</sub>(M) where z<sub>i</sub> = **E<sub>K</sub>**(z<sub>i-1</sub> ⊕ **M<sub>i</sub>**).
# \
