# %% [markdown]
# ## Can you break this Caesar Cipher?
#
# (Hint: write a for loop)

# %%
cipher = "Ro)x~)|ynwm)vx{n)xw)lxoonn)}qjw)xw)R])|nl~{r}5)x~)ruu)kn)qjltnm7"
print(cipher)
# Out:
# Ro)x~)|ynwm)vx{n)xw)lxoonn)}qjw)xw)R])|nl~{r}5)x~)ruu)kn)qjltnm7

# %% [markdown]
# ## How about this Vigenere Cipher?
#
# (Hint: try this tool -- https://www.dcode.fr/chiffre-vigenere)

# %%
cipher = "Oaii wbdnbrb tegteihw, qay tx olr jghxn maklxey ss bmlx cepcagk vx gzw eivzrk."
print(cipher)
# Out:
# Oaii wbdnbrb tegteihw, qay tx olr jghxn maklxey ss bmlx cepcagk vx gzw eivzrk.

# %% [markdown]
# ## One more? This message is encrypted with Rail Fence (Zig Zag) cipher.
#
# (No hints! 🤖)

# %%
cipher = "Arkedeacpmusc tmn fsnlakolae asssapososh eethy ri p."
print(cipher)
# Out:
# Arkedeacpmusc tmn fsnlakolae asssapososh eethy ri p.
